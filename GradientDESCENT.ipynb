# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X=np.arange(0,10)
fn=(x-5)**2+3
Y=np.array([])
for  i in range(0,len(X)):
   Y=np.append(Y,(X[i]-5)**2+3)
Y
# Out:
# array([28., 19., 12.,  7.,  4.,  3.,  4.,  7., 12., 19.])

# %%
plt.plot(X,Y)

# %%
from sympy import *
import numpy as np
eta=0.1
x = Symbol('x')
y = (x-5)**2+3
yprime = y.diff(x)

f = lambdify(x, yprime, 'numpy')

# %%
yprime
# Out:
# 2*x - 10

# %%
gd=[]
x=20
for i in range(50):
    xn=x-eta*(2*x-10)
    y=(x-5)**2+3
    x=xn
    plt.plot(X,Y)
    plt.scatter(xn,y)
    print(xn)
    
    gd.append(xn)

x=np.arange(0,50)
# Out:
# 17.0
# 14.6
# 12.68
# 11.144
# 9.9152
# 8.93216
# 8.145728
# 7.5165824
# 7.01326592
# 6.610612736
# 6.2884901888
# 6.03079215104
# 5.824633720832
# 5.6597069766656
# 5.5277655813324795
# 5.422212465065984
# 5.337769972052787
# 5.27021597764223
# 5.216172782113784
# 5.172938225691027
# 5.138350580552822
# 5.110680464442257
# 5.088544371553806
# 5.070835497243045
# 5.056668397794436
# 5.045334718235549
# 5.036267774588439
# 5.029014219670751
# 5.023211375736601
# 5.01856910058928
# 5.014855280471425
# 5.011884224377139
# 5.009507379501711
# 5.007605903601369
# 5.006084722881095
# 5.004867778304876
# 5.0038942226439005
# 5.003115378115121
# 5.002492302492096
# 5.001993841993677
# 5.001595073594942
# 5.001276058875954
# 5.001020847100763
# 5.000816677680611
# 5.0006533421444885
# 5.000522673715591
# 5.0004181389724724
# 5.000334511177978
# 5.000267608942382
# 5.000214087153905
